# %%
1+1
# Out:
# 2

# %%
import pandas as pd

# %%
df = pd.read_csv('to_predict.csv')

# %%
df
# Out:
#           Date  btc_price  btc_open  btc_high  btc_low  btc_change  \
# 0   2024-05-20        NaN       NaN       NaN      NaN         NaN
# 1   2024-05-21    70139.9   71430.5   71872.0  69181.7       -1.81
# 2   2024-05-22    69155.4   70141.0   70593.4  69024.3       -1.41
# 3   2024-05-23    67975.7   69166.3   70041.0  66578.1       -1.72
# 4   2024-05-24    68547.6   67971.1   69212.0  66685.8        0.85
# 5   2024-05-25    69284.4   68548.2   69558.8  68516.1        1.07
# 6   2024-05-26    68514.8   69287.2   69494.0  68294.5       -1.11
# 7   2024-05-27    69428.7   68514.6   70638.3  68275.2        1.33
# 8   2024-05-28    68366.0   69428.3   69560.7  67299.9       -1.53
# 9   2024-05-29    67635.8   68366.2   68897.6  67143.2       -1.07
# 10  2024-05-30    69349.0   67631.3   69349.5  67138.4        2.54
#
#     gold_price  gold_open  gold_high  gold_low  ...  us30_high  us30_low  \
# 0          NaN        NaN        NaN       NaN  ...        NaN       NaN
# ...

# %%
df_new = df[['Date','btc_price','btc_open','btc_high','btc_low','btc_change','btc_rsi']]

# %%
df_new
# Out:
#           Date  btc_price  btc_open  btc_high  btc_low  btc_change    btc_rsi
# 0   2024-05-20        NaN       NaN       NaN      NaN         NaN        NaN
# 1   2024-05-21    70139.9   71430.5   71872.0  69181.7       -1.81  66.711532
# 2   2024-05-22    69155.4   70141.0   70593.4  69024.3       -1.41  67.071772
# 3   2024-05-23    67975.7   69166.3   70041.0  66578.1       -1.72  60.847008
# 4   2024-05-24    68547.6   67971.1   69212.0  66685.8        0.85  68.556639
# 5   2024-05-25    69284.4   68548.2   69558.8  68516.1        1.07  69.586402
# 6   2024-05-26    68514.8   69287.2   69494.0  68294.5       -1.11  66.203840
# 7   2024-05-27    69428.7   68514.6   70638.3  68275.2        1.33  65.336257
# 8   2024-05-28    68366.0   69428.3   69560.7  67299.9       -1.53  66.291925
# 9   2024-05-29    67635.8   68366.2   68897.6  67143.2       -1.07  54.165461
# 10  2024-05-30    69349.0   67631.3   69349.5  67138.4        2.54  61.664136

# %%
df_new2 = df_new.tail(10)

# %%
df_new2.set_index('Date')
# Out:
#             btc_price  btc_open  btc_high  btc_low  btc_change    btc_rsi
# Date
# 2024-05-21    70139.9   71430.5   71872.0  69181.7       -1.81  66.711532
# 2024-05-22    69155.4   70141.0   70593.4  69024.3       -1.41  67.071772
# 2024-05-23    67975.7   69166.3   70041.0  66578.1       -1.72  60.847008
# 2024-05-24    68547.6   67971.1   69212.0  66685.8        0.85  68.556639
# 2024-05-25    69284.4   68548.2   69558.8  68516.1        1.07  69.586402
# 2024-05-26    68514.8   69287.2   69494.0  68294.5       -1.11  66.203840
# 2024-05-27    69428.7   68514.6   70638.3  68275.2        1.33  65.336257
# 2024-05-28    68366.0   69428.3   69560.7  67299.9       -1.53  66.291925
# 2024-05-29    67635.8   68366.2   68897.6  67143.2       -1.07  54.165461
# 2024-05-30    69349.0   67631.3   69349.5  67138.4        2.54  61.664136

# %%
df_new3 = df_new2.set_index('Date')

# %%
df_new3.tail(5).to_csv('bitcoin.csv', index=True)

# %%
import datetime
from datetime import date, timedelta

# %%
x= date.today()

# %%
x
# Out:
# datetime.date(2024, 5, 31)

# %%
x - timedelta(days=7)
# Out:
# datetime.date(2024, 5, 24)
